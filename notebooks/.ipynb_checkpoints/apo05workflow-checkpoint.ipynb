# %% [markdown]
# # apo05 Workflow Demo
# This is the demo data we've used a lot... it's originally from SLH, used to teach APO observing class for years!
#
# Use it to debug all the functions, flush out the slightly updated workflow
#
# Not a robust tutorial, but useful!

# %%
 # need notebook backend for interaction
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# file-handling stuff for user, options abound! I like Tables and Pandas DataFrames
import pandas as pd
from astropy.table import Table
from astropy import units as u

# import kosmos... if we do it right this should be the only other thing to import someday!
import sys  
sys.path.append('..')

import kosmos
kosmos.__version__
# Out:
# '0.1'

# %%
# should we make a whole bunch of plots?
DISPLAY = True

# %% [markdown]
# ## 1. Bias

# %%
# current fits dir 'C:/Users/josue/kosmos-testing/test'

# %%
# to run on data, the user should provide lists of files to reduce.
# we can do this via the old IRAF way for now (b/c I'm old fashioned),
# but probably could design a more pythonic way (e.g. w/ glob or similar)

dir = "C:/Users/josue/kosmos-testing/test/"
biasfiles_i = pd.read_table(dir + 'biaslist.txt', names=['impath'])
biasfiles = dir + biasfiles_i['impath'].values
biasfiles
# Out:
# array(['C:/Users/josue/kosmos-testing/test/05may31.0022r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0023r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0024r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0025r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0026r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0027r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0028r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0029r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0030r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0031r.fits'],
#       dtype=object)

# %%
# use simple wrapper for median bias combining
bias = kosmos.biascombine(biasfiles) 
print(bias.shape)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(bias, origin='lower', aspect='auto', cmap=plt.cm.gray)
    plt.title('median bias frame')
    plt.clim(np.percentile(bias, (5, 98)))
    cb = plt.colorbar()
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'Mount' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.468169 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.468719 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.469266 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.469811 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.470358 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.470903 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.471449 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.471995 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.472541 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.473087 from DATE-OBS'. [astropy.wcs.wcs]
# (1078, 2098)

# %% [markdown]
# ## 2. Flat

# %%
flatfiles_i = pd.read_table(dir + 'flatlist.txt', names=['impath'])
flatfiles = dir + flatfiles_i['impath'].values
flatfiles
# Out:
# array(['C:/Users/josue/kosmos-testing/test/05may31.0037r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0038r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0039r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0040r.fits',
#        'C:/Users/josue/kosmos-testing/test/05may31.0041r.fits'],
#       dtype=object)

# %%
# a wrapper around Combiner, the spectral response normalization, and the illumination correction
# this should work WITH or WITHOUT a bias given
flat, ilum = kosmos.flatcombine(flatfiles, bias=bias)

print(ilum.shape) # this is the indicies that are illuminated
print(flat.shape)
print(flat.unit)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(flat, origin='lower', aspect='auto', cmap=plt.cm.inferno)
    plt.clim(.9,1.1)
    plt.title('median flat, bias & response corrected')
    cb = plt.colorbar()
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.478531 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.479778 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.481027 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.482277 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.483525 from DATE-OBS'. [astropy.wcs.wcs]
# C:\Users\josue\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:753: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# (748,)
# (748, 2048)
# adu / s

# %%
# if you turn off the illumination and response corrections, you just get a normalized median combined image
# i.e. could be used for photometry
medflat = kosmos.flatcombine(flatfiles, illumcor=False, responsecor=False)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(medflat, origin='lower', aspect='auto', cmap=plt.cm.inferno)
    plt.clim(np.percentile(medflat, (5, 98)))
    plt.title('median flat, NO corrections')
    cb = plt.colorbar()

print(medflat.shape)
print(medflat.unit)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'Mount' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.478531 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.479778 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.481027 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.482277 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.483525 from DATE-OBS'. [astropy.wcs.wcs]
# (1028, 2048)
# adu / s

# %%
# how to read in any science or calibration frame w/ a spectrum present

sci = dir + '05may31.0010r.fits'  # spectrum of the one target star, Gl 669A
sciimg = kosmos.proc(sci, bias=bias, ilum=ilum, flat=flat, trim=True)

print(sciimg.shape)
print(sciimg.unit)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(sciimg, origin='lower', aspect='auto')
    plt.clim(np.percentile(sciimg, (5, 98)))
    cb = plt.colorbar()
    plt.title(sci)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.384752 from DATE-OBS'. [astropy.wcs.wcs]
# (748, 2048)
# adu / s

# %%
fcal = dir + '05may31.0020r.fits' # Flux std star observation, BD+282411

calimg = kosmos.proc(fcal, bias=bias, ilum=ilum, flat=flat, trim=True)
print(sciimg.shape)
print(sciimg.unit)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(calimg, origin='lower', aspect='auto', cmap=plt.cm.Spectral_r)
    plt.clim(np.percentile(calimg, (5, 98)))
    cb = plt.colorbar()
    plt.title(fcal)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.452930 from DATE-OBS'. [astropy.wcs.wcs]
# (748, 2048)
# adu / s

# %% [markdown]
# ## 4. Trace & Extract

# %%
cal_trace = kosmos.trace(calimg, display=DISPLAY, nbins=25)
sci_trace = kosmos.trace(sciimg, display=False, nbins=55)

sci_trace.shape
# Out:
# C:\Users\josue\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:753: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# C:\Users\josue\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:753: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# (2048,)

# %%
sci_ex, sci_sky = kosmos.BoxcarExtract(sciimg, sci_trace, display=DISPLAY, apwidth=10, skysep=5, skywidth=5)
cal_ex, cal_sky = kosmos.BoxcarExtract(calimg, cal_trace, display=False, apwidth=10, skysep=5, skywidth=5)

# %%
if DISPLAY:
    plt.errorbar(sci_ex.spectral_axis.value, sci_ex.flux.value - sci_sky.flux.value, 
                 yerr=sci_ex.uncertainty.array, linestyle='none')
    plt.xlabel(sci_ex.spectral_axis.unit)
    plt.ylabel(sci_ex.flux.unit)
    plt.title('Boxcar extract - sky')

# %% [markdown]
# ## 5. Wavelength Calibration
# This is (in my opinion) the hardest part of the entire pipeline.

# %%
arcfile = dir + '05may31.0035r.fits' # HeNeAr lamp
# read and process in the ARC LAMP, just like a normal spectrum
arcimg = kosmos.proc(arcfile, bias=bias, ilum=ilum, trim=True) 

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(arcimg, origin='lower', aspect='auto', cmap=plt.cm.afmhot)
    plt.plot(np.arange(len(sci_trace)), sci_trace) # for illustration, overplot the trace 
    plt.clim(np.percentile(arcimg, (5, 97)))
    cb = plt.colorbar()
    plt.title(arcfile)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'Mount' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.476553 from DATE-OBS'. [astropy.wcs.wcs]

# %%
# this data comes from the APO DIS red channel, which has wavelength axis backwards
# (despite not mentioning in the header...)
wapprox = (np.arange(sciimg.shape[1]) - sciimg.shape[1]/2)[::-1] * sciimg.header['DISPDW'] + sciimg.header['DISPWC']
wapprox = wapprox * u.angstrom

if DISPLAY:
    plt.errorbar(wapprox.value, sci_ex.flux.value - sci_sky.flux.value, 
                 yerr=sci_ex.uncertainty.array, linestyle='none')
    plt.xlabel(wapprox.unit)
    plt.ylabel(sci_ex.flux.unit)
    plt.title('Boxcar extract - sky')

# %%
# extract the trace across the Arc lamp image
sciarc_ex, _ = kosmos.BoxcarExtract(arcimg, sci_trace, apwidth=3, skysep=5, skywidth=5)
calarc_ex, _ = kosmos.BoxcarExtract(arcimg, cal_trace, apwidth=3, skysep=5, skywidth=5)

if DISPLAY:
    plt.plot(sciarc_ex.spectral_axis.value, sciarc_ex.flux.value)
    plt.xlabel(sciarc_ex.spectral_axis.unit)
    plt.ylabel(sciarc_ex.flux.unit)

# plt.ylim(-10,85)
# wow... so many little features here that could be used by DTW!
# Out:
# C:\Users\josue\kosmos\notebooks\..\kosmos\apextract.py:335: RuntimeWarning: invalid value encountered in sqrt
#   fluxerr[i] = np.sqrt(np.nansum((onedspec[i]-skysubflux[i])) +

# %%
# a table of strong HeNeAr lines for the instrument in question, w/ units
# apo_henear = Table.read(dir+'apohenear.ecsv', format='ascii.ecsv')['wave']


# The old IRAF-style linelists just have 2 col: (wavelength, line name)
henear_tbl = Table.read('../kosmos/resources/linelists/apohenear.dat', 
                        names=('wave', 'name'), format='ascii')
# IMPROVEMENT NEEDED: need to make `identify_nearest` point to these linelists itself?

henear_tbl['wave'].unit = u.angstrom
apo_henear = henear_tbl['wave']

# %%
# use the "nearest" mode, which uses a list of known line features, and the
# approx wavelength from the header info. Starts in the middle, tries to find nearest
# peaks to those in the catalog... it works ok-ish for some modes

sci_xpts, sci_wpts = kosmos.identify_nearest(sciarc_ex, wapprox=wapprox, linewave=apo_henear, autotol=5)
# Out:
# 19 lines matched from 20 within estimated range.

# %%
sci_xpts
# Out:
# array([ 359.69912256,  398.79510201,  520.98210502,  771.86347869,
#         817.57534447,  910.88307912,  988.59453671, 1019.59957675,
#        1142.25699226, 1164.91233446, 1222.06047995, 1256.94943369,
#        1302.04323081, 1360.01756229, 1423.34840306, 1447.58899816,
#        1503.00022427, 1528.79898629, 1764.5435791 ])

# %%
print(cal_ex)
print(cal_sky)
# Out:
# Spectrum1D (length=2048)
# flux:             [ 41.231 adu / s, ..., 59.133 adu / s ],  mean=75.274 adu / s
# spectral axis:    [ 0.0 pix, ..., 2047.0 pix ],  mean=1023.5 pix
# uncertainty:      [ StdDevUncertainty(6.40328706), ..., StdDevUncertainty(7.60553919) ]
# Spectrum1D (length=2048)
# flux:             [ 0.24072 adu / s, ..., 1.298 adu / s ],  mean=1.1246 adu / s
# spectral axis:    [ 0.0 pix, ..., 2047.0 pix ],  mean=1023.5 pix

# %%
# subtract the sky from the actual spectrum
cal_spectrum = cal_ex  - cal_sky
sci_spectrum = sci_ex - sci_sky
cal_spectrum
# Out:
# ---------------------------------------------------------------------------
# UnitTypeError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24356/1262572341.py in <module>
#       1 # subtract the sky from the actual spectrum
# ----> 2 cal_spectrum = cal_ex  - cal_sky
#       3 sci_spectrum = sci_ex - sci_sky
#       4 cal_spectrum
#
# ~\AppData\Roaming\Python\Python39\site-packages\specutils\spectra\spectrum1d.py in __sub__(self, other)
#     634             other = u.Quantity(other, unit=self.unit)
#     635
# --> 636         return self.subtract(other)
#     637
#     638     def __mul__(self, other):
#
# ~\anaconda3\lib\site-packages\astropy\nddata\mixins\ndarithmetic.py in subtract(self, operand, operand2, **kwargs)
#     522     @format_doc(_arit_doc, name='subtraction', op='-')
#     523     def subtract(self, operand, operand2=None, **kwargs):
# --> 524         return self._prepare_then_do_arithmetic(np.subtract, operand, operand2,
#     525                                                 **kwargs)
#     526
#
# ~\anaconda3\lib\site-packages\astropy\nddata\mixins\ndarithmetic.py in _prepare_then_do_arithmetic(self_or_cls, operation, operand, operand2, **kwargs)
#     614
#     615         # Return a new class based on the result
# --> 616         return cls(result, **init_kwds)
#
# ~\AppData\Roaming\Python\Python39\site-packages\specutils\spectra\spectrum1d.py in __init__(self, flux, spectral_axis, wcs, velocity_convention, rest_value, redshift, radial_velocity, bin_specification, **kwargs)
#     281                     spec_axis = self.wcs.spectral.pixel_to_world(np.arange(self.flux.shape[-1]))
#     282             else:
# --> 283                 spec_axis = self.wcs.pixel_to_world(np.arange(self.flux.shape[-1]))
#     284
#     285             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\specutils\utils\wcs_utils.py in pixel_to_world(self, *args, **kwargs)
#     215             if orig_array.unit == '':
#     216                 return u.Quantity(super().pixel_to_world_values(*args, **kwargs))
# --> 217             return super().pixel_to_world(*args, **kwargs).to(
#     218                 orig_array.unit, equivalencies=u.spectral())
#     219
#
# ~\AppData\Roaming\Python\Python39\site-packages\gwcs\api.py in pixel_to_world(self, *pixel_arrays)
#     297         """
#     298         pixels = self._sanitize_pixel_inputs(*pixel_arrays)
# --> 299         return self(*pixels, with_units=True)
#     300
#     301     def array_index_to_world(self, *index_arrays):
#
# ~\AppData\Roaming\Python\Python39\site-packages\gwcs\wcs.py in __call__(self, *args, **kwargs)
#     378         if with_units:
#     379             if self.output_frame.naxes == 1:
# --> 380                 result = self.output_frame.coordinates(result)
#     381             else:
#     382                 result = self.output_frame.coordinates(*result)
#
# ~\AppData\Roaming\Python\Python39\site-packages\gwcs\coordinate_frames.py in coordinates(self, *args)
#     461         else:
#     462             if hasattr(args[0], 'unit'):
# --> 463                 return coord.SpectralCoord(*args).to(self.unit[0])
#     464             else:
#     465                 return coord.SpectralCoord(*args, self.unit[0])
#
# ~\anaconda3\lib\site-packages\astropy\units\decorators.py in wrapper(*func_args, **func_kwargs)
#     300             # Call the original function with any equivalencies in force.
#     301             with add_enabled_equivalencies(self.equivalencies):
# --> 302                 return_ = wrapped_function(*func_args, **func_kwargs)
#     303
#     304             # Return
#
# ~\anaconda3\lib\site-packages\astropy\coordinates\spectral_coordinate.py in __new__(cls, value, unit, observer, target, radial_velocity, redshift, **kwargs)
#     174                 **kwargs):
#     175
# --> 176         obj = super().__new__(cls, value, unit=unit, **kwargs)
#     177
#     178         # There are two main modes of operation in this class. Either the
#
# ~\anaconda3\lib\site-packages\astropy\coordinates\spectral_quantity.py in __new__(cls, value, unit, doppler_rest, doppler_convention, **kwargs)
#      55                 **kwargs):
#      56
# ---> 57         obj = super().__new__(cls, value, unit=unit, **kwargs)
#      58
#      59         # If we're initializing from an existing SpectralQuantity, keep any
#
# ~\anaconda3\lib\site-packages\astropy\units\quantity.py in __new__(cls, value, unit, dtype, copy, order, subok, ndmin)
#     420             if type(value) is not cls and not (subok and
#     421                                                isinstance(value, cls)):
# --> 422                 value = value.view(cls)
#     423
#     424             if dtype is None and value.dtype.kind in 'iu':
#
# ~\anaconda3\lib\site-packages\astropy\coordinates\spectral_coordinate.py in __array_finalize__(self, obj)
#     223
#     224     def __array_finalize__(self, obj):
# --> 225         super().__array_finalize__(obj)
#     226         self._radial_velocity = getattr(obj, '_radial_velocity', None)
#     227         self._observer = getattr(obj, '_observer', None)
#
# ~\anaconda3\lib\site-packages\astropy\coordinates\spectral_quantity.py in __array_finalize__(self, obj)
#      70
#      71     def __array_finalize__(self, obj):
# ---> 72         super().__array_finalize__(obj)
#      73         self._doppler_rest = getattr(obj, '_doppler_rest', None)
#      74         self._doppler_convention = getattr(obj, '_doppler_convention', None)
#
# ~\anaconda3\lib\site-packages\astropy\units\quantity.py in __array_finalize__(self, obj)
#     545             unit = getattr(obj, '_unit', None)
#     546             if unit is not None:
# --> 547                 self._set_unit(unit)
#     548
#     549         # Copy info if the original had `info` defined.  Because of the way the
#
# ~\anaconda3\lib\site-packages\astropy\units\quantity.py in _set_unit(self, unit)
#    1936     def _set_unit(self, unit):
#    1937         if unit is None or not unit.is_equivalent(self._equivalent_unit):
# -> 1938             raise UnitTypeError(
#    1939                 "{} instances require units equivalent to '{}'"
#    1940                 .format(type(self).__name__, self._equivalent_unit) +
#
# UnitTypeError: SpectralCoord instances require units equivalent to '(Unit("Hz"), Unit("m"), Unit("J"), Unit("1 / m"), Unit("km / s"))', so cannot set it to 'pix'.

# %%
cal_fit = kosmos.fit_wavelength(cal_spectrum, sci_xpts, sci_wpts, mode='interp', deg=3)
sci_fit = kosmos.fit_wavelength(sci_spectrum, sci_xpts, sci_wpts, mode='interp', deg=3)

if DISPLAY:
    plt.plot(sci_fit.spectral_axis, sci_fit.flux)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24356/2466127196.py in <module>
# ----> 1 cal_fit = kosmos.fit_wavelength(cal_spectrum, sci_xpts, sci_wpts, mode='interp', deg=3)
#       2 sci_fit = kosmos.fit_wavelength(sci_spectrum, sci_xpts, sci_wpts, mode='interp', deg=3)
#       3
#       4 if DISPLAY:
#       5     plt.plot(sci_fit.spectral_axis, sci_fit.flux)
#
# ~\kosmos\notebooks\..\kosmos\identify.py in fit_wavelength(spec, xpoints, wpoints, display, mode, deg, GPRscale, returnpoints, returnvar)
#     555     if mode.lower() == 'interp':
#     556         spl = interp1d(xpt, wpt, kind=deg, fill_value='extrapolate')
# --> 557         wavesolved = spl(spec.spectral_axis.value)
#     558         fpt = spl(xpt)
#     559
#
# AttributeError: 'numpy.ndarray' object has no attribute 'spectral_axis'

# %% [markdown]
# ## 4. Airmass & Flux Calibration

# %%
# Get the airmass from the Headers... no fancy way to do this I guess? 
ZD = sciimg.header['ZD'] / 180.0 * np.pi
sci_airmass = 1.0/np.cos(ZD) # approximate Zenith Distance -> Airmass conversion

ZD = calimg.header['ZD'] / 180.0 * np.pi
cal_airmass = 1.0/np.cos(ZD)

print(sci_airmass, cal_airmass)

# %%
# Select the observatory-specific airmass extinction profile from the provided "extinction" library
Xfile = kosmos.obs_extinction('apoextinct.dat')
# Xfile

# %%
# apply the airmass correction
cal_fitX = kosmos.airmass_cor(cal_fit, cal_airmass, Xfile)
sci_fitX = kosmos.airmass_cor(sci_fit, sci_airmass, Xfile)

# %%
# Select the Standard Star reference spectrum from the provided "onedstd" library
standardstar = kosmos.onedstd('spec50cal/bd284211.dat')
# standardstar

# %%
# this is the sensitivity function, which converts the CCD data from
# ADU/S -> erg/s/cm2/A
sensfunc = kosmos.standard_sensfunc(cal_fitX, standardstar, mode='linear', display=False)

if DISPLAY:
    plt.plot(sensfunc.spectral_axis, sensfunc.flux)
    plt.xlabel('wavelength')
    plt.ylabel('sensfunc')
    
sensfunc.flux.unit

# %%
# convert from air to vac wavelength

# sci_fitX = kosmos.air_to_vac(sci_fitX)

# %%
final_spectrum = kosmos.apply_sensfunc(sci_fitX, sensfunc)

if DISPLAY:
    plt.plot(final_spectrum.wavelength, final_spectrum.flux, c='k')

    # having to convert the Spectrum1D parameters like this is annoying,
    # and also inconsistent behavior with the uncertainty
    plt.errorbar(final_spectrum.wavelength.value, final_spectrum.flux.value, 
                 yerr=final_spectrum.uncertainty.array, alpha=0.2, c='C5')

    plt.xlabel('Wavelength ['+str(final_spectrum.wavelength.unit)+']')
    plt.ylabel('Flux ['+str(final_spectrum.flux.unit)+']')
    plt.title('Gl 669A – workflow example reduction')
    
final_spectrum.flux.unit # units check out!

# %%
# Read in the IRAF-reduced version!
from astropy.nddata import CCDData
# dir = '../kosmos/testdata/slh05_test/apo05/'
img = CCDData.read('../kosmos/testdata/slh05_test/slh_reduction/gl669cal.fits', hdu=0)
# img.wcs

plt.figure(figsize=(9,4))
plt.plot(final_spectrum.wavelength, final_spectrum.flux, c='k', label='New reduction', alpha=0.7)

# having to convert the Spectrum1D parameters like this is annoying
# and also inconsistent behavior with the uncertainty
# plt.errorbar(final_spectrum.wavelength.value, final_spectrum.flux.value, 
#              yerr=final_spectrum.uncertainty.array, alpha=0.2, c='C5')

# coefficients manually taken from the WCS info in the header, 
# b/c I can't figure out how to access them progamatically...
plt.plot(5654.8668211415 + np.arange(2006)*0.84311144412739, img.data[0,0,:], 
         label='IRAF reduction', alpha=.7)

plt.xlabel('Wavelength ['+str(final_spectrum.wavelength.unit)+']')
plt.ylabel('Flux ['+str(final_spectrum.flux.unit)+']')
plt.title('Gl 669A – SLH example data')
plt.legend()

# %%
# TO DO: might want to also add Telluric Correction, examples with TelFit...
# https://telfit.readthedocs.io/en/latest/
