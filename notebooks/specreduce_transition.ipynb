# %% [markdown]
# How many of these pykosmos functions can be offloaded to specreduce now? Many of the specreduce functions *came* from pykosmos originally, now we can benefit from their development!

# %%
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt

# file-handling stuff for user, options abound! I like Tables and Pandas DataFrames
import pandas as pd
from astropy.table import Table
from astropy import units as u
from specutils import Spectrum1D

import specreduce

import sys
sys.path.insert(0,'/Users/james/Dropbox/research_projects/pykosmos')

import pykosmos as pk
pk.__version__
# Out:
# '0.3.7'

# %%
specreduce.__version__
# Out:
# '1.4.1'

# %%
# should we make a whole bunch of plots?
DISPLAY = True

# %% [markdown]
# ## 1. Bias

# %%
# to run on data, the user should provide lists of files to reduce.
# we can do this via the old IRAF way for now (b/c I'm old fashioned),
# but probably could design a more pythonic way (e.g. w/ glob or similar)

dir = '../../pykosmos_testdata/slh05_test/apo05/'
biasfiles_i = pd.read_table(dir + 'biaslist.txt', names=['impath'])
biasfiles = dir + biasfiles_i['impath'].values
biasfiles
# Out:
# array(['../../pykosmos_testdata/slh05_test/apo05/05may31.0022r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0023r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0024r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0025r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0026r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0027r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0028r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0029r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0030r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0031r.fits'],
#       dtype=object)

# %%
# use simple wrapper for median bias combining
bias = pk.biascombine(biasfiles) 
print(bias.shape)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(bias, origin='lower', aspect='auto', cmap=plt.cm.gray)
    plt.title('median bias frame')
    plt.clim(np.percentile(bias, (5, 98)))
    cb = plt.colorbar()
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'Mount' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.468169 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.468719 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.469266 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.469811 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.470358 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.470903 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.471449 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.471995 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.472541 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.473087 from DATE-OBS'. [astropy.wcs.wcs]
# (1078, 2098)
# /Users/james/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4823: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 2. Flat

# %%
flatfiles_i = pd.read_table(dir + 'flatlist.txt', names=['impath'])
flatfiles = dir + flatfiles_i['impath'].values
flatfiles
# Out:
# array(['../../pykosmos_testdata/slh05_test/apo05/05may31.0037r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0038r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0039r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0040r.fits',
#        '../../pykosmos_testdata/slh05_test/apo05/05may31.0041r.fits'],
#       dtype=object)

# %%
# a wrapper around Combiner, the spectral response normalization, and the illumination correction
# this should work WITH or WITHOUT a bias given
flat, ilum = pk.flatcombine(flatfiles, bias=bias)

print(ilum.shape) # this is the indicies that are illuminated
print(flat.shape)
print(flat.unit)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(flat, origin='lower', aspect='auto', cmap=plt.cm.inferno)
    plt.clim(.9,1.1)
    plt.title('median flat, bias & response corrected')
    cb = plt.colorbar()
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'Mount' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.478531 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.479778 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.481027 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.482277 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.483525 from DATE-OBS'. [astropy.wcs.wcs]
# (748,)
# (748, 2048)
# adu / s
# /Users/james/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:771: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# if you turn off the illumination and response corrections, you just get a normalized median combined image
# i.e. could be used for photometry
medflat = pk.flatcombine(flatfiles, illumcor=False, responsecor=False)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(medflat, origin='lower', aspect='auto', cmap=plt.cm.inferno)
    plt.clim(np.percentile(medflat, (5, 98)))
    plt.title('median flat, NO corrections')
    cb = plt.colorbar()

print(medflat.shape)
print(medflat.unit)
# Out:
# (1028, 2048)
# adu / s
# /Users/james/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4823: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# how to read in any science or calibration frame w/ a spectrum present

sci = dir + '05may31.0010r.fits'  # spectrum of the one target star, Gl 669A
sciimg = pk.proc(sci, bias=bias, ilum=ilum, flat=flat, trim=True)

print(sciimg.shape)
print(sciimg.unit)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(sciimg, origin='lower', aspect='auto')
    plt.clim(np.percentile(sciimg, (5, 98)))
    cb = plt.colorbar()
    plt.title(sci)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.384752 from DATE-OBS'. [astropy.wcs.wcs]
# (748, 2048)
# adu / s
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fcal = dir + '05may31.0020r.fits' # Flux std star observation, BD+282411

calimg = pk.proc(fcal, bias=bias, ilum=ilum, flat=flat, trim=True)
print(sciimg.shape)
print(sciimg.unit)

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(calimg, origin='lower', aspect='auto', cmap=plt.cm.Spectral_r)
    plt.clim(np.percentile(calimg, (5, 98)))
    cb = plt.colorbar()
    plt.title(fcal)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.452930 from DATE-OBS'. [astropy.wcs.wcs]
# (748, 2048)
# adu / s
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 4. Trace & Extract - THE PYKOSMOS WAY
# Note these functions are simply wrappers around the specreduce methods (which were based on the previous versions from PyKOSMOS!)

# %%
# the pykosmos function
cal_trace = pk.trace(calimg, display=DISPLAY, nbins=25)
sci_trace = pk.trace(sciimg, display=False, nbins=55)
# Out:
# /var/folders/8t/yh7p62792_b_y17g3f6wk0wm0000gn/T/ipykernel_16504/2508456919.py:2: DeprecationWarning: PyKOSMOS trace is now a wrapper for functions within specreduce.tracing, and is kept for backwards compatibility. More features are available from specreduce.tracing.
#   cal_trace = pk.trace(calimg, display=DISPLAY, nbins=25)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /var/folders/8t/yh7p62792_b_y17g3f6wk0wm0000gn/T/ipykernel_16504/2508456919.py:3: DeprecationWarning: PyKOSMOS trace is now a wrapper for functions within specreduce.tracing, and is kept for backwards compatibility. More features are available from specreduce.tracing.
#   sci_trace = pk.trace(sciimg, display=False, nbins=55)

# %%
# sci_ex, sci_sky = pk.BoxcarExtract(sciimg, sci_trace, apwidth=10, skysep=25, skywidth=5, 
#                                    bkgd_sub=False, return_sky=True)
# cal_ex, cal_sky = pk.BoxcarExtract(calimg, cal_trace, apwidth=10, skysep=25, skywidth=5, 
#                                    bkgd_sub=False, return_sky=True)

# # subtract the sky from the extracted spectrum if you need to
# sci_spectrum = sci_ex.subtract(sci_sky, compare_wcs=None)
# cal_spectrum = cal_ex.subtract(cal_sky, compare_wcs=None)

# NOTE this is the default way now:
sci_spectrum = pk.BoxcarExtract(sciimg, sci_trace, apwidth=10, skysep=10, skywidth=10)
cal_spectrum = pk.BoxcarExtract(calimg, cal_trace, apwidth=10, skysep=10, skywidth=10)
# Out:
# /var/folders/8t/yh7p62792_b_y17g3f6wk0wm0000gn/T/ipykernel_16504/940506800.py:11: DeprecationWarning: PyKOSMOS BoxcarExtract is now a wrapper for functions within specreduce.extract.
#   sci_spectrum = pk.BoxcarExtract(sciimg, sci_trace, apwidth=10, skysep=10, skywidth=10)
# /var/folders/8t/yh7p62792_b_y17g3f6wk0wm0000gn/T/ipykernel_16504/940506800.py:12: DeprecationWarning: PyKOSMOS BoxcarExtract is now a wrapper for functions within specreduce.extract.
#   cal_spectrum = pk.BoxcarExtract(calimg, cal_trace, apwidth=10, skysep=10, skywidth=10)

# %%
if DISPLAY:
    plt.figure()
    plt.errorbar(sci_spectrum.spectral_axis.value, sci_spectrum.flux.value,
                 yerr=sci_spectrum.uncertainty.array, linestyle='none')
    # plt.plot(sci_spectrum.spectral_axis.value, sci_spectrum.flux.value)
    plt.xlabel(sci_spectrum.spectral_axis.unit)
    plt.ylabel(sci_spectrum.flux.unit)
    plt.title('Boxcar extract')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 4. Trace & Extract - THE NEW SPECREDUCE WAY
# If you want to use specreduce directly, you can do that also! This should produce about the same result as the wrapped versions above, but doesn't produce an uncertainty on the flux.

# %%
from specreduce.tracing import FitTrace, ArrayTrace
from astropy.modeling import models
from specreduce.background import Background
from specreduce.extract import BoxcarExtract

# %%
sci_trace = FitTrace(sciimg, bins=20, peak_method='gaussian', guess=385, window=100, trace_model=models.Spline1D())
cal_trace = FitTrace(calimg, bins=20, peak_method='gaussian', guess=385, window=100, trace_model=models.Spline1D())

# %%
plt.figure(figsize=(6,3))
plt.imshow(sciimg, origin='lower', aspect='auto', cmap=plt.cm.gray)
plt.clim(np.percentile(sciimg, (5, 98)))
cb = plt.colorbar()
plt.title(sci)

plt.plot(sci_trace.trace.data, label='new trace')
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sci_bg = Background.two_sided(sciimg, sci_trace, separation=25, width=5)
cal_bg = Background.two_sided(calimg, cal_trace, separation=25, width=5)

plt.figure()
plt.plot(sci_bg.bkg_spectrum().flux)
plt.plot(cal_bg.bkg_spectrum().flux)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sci_spectrum_new = BoxcarExtract(sciimg-sci_bg, sci_trace, width=5)
cal_spectrum_new = BoxcarExtract(calimg-cal_bg, cal_trace, width=5)

plt.figure()
plt.plot(sci_spectrum_new.spectrum.flux) # new boxcar extract doesnt do flux errors by default, we'll need to fix that
# plt.plot(sci_spectrum_old.flux)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 5. Wavelength Calibration

# %%
# what calibrated arc templates are available?
# (we should build some explicitly for ALL lamps at APO!)
pk.loadarctemplate(help=True)
# Out:
# ['/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/KrRed0.86-high.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/KrRed1.18-ctr.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/KrBlue1.18-ctr.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/KrBlue0.86-high.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/ArRed2.0-low.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/NeBlue2.0-low.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/ArRed1.18-ctr.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/NeBlue1.18-ctr.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/ArBlue2.0-low.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/ArRed0.86-high.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/KrRed2.0-low.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/NeRed1.18-ctr.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/NeRed2.0-low.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/ArBlue1.18-ctr.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/ArBlue0.86-high.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/NeRed0.86-high.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/KrBlue2.0-low.spec',
#  '/Users/james/Dropbox/research_projects/pykosmos/pykosmos/resources/arctemplates/NeBlue0.86-high.spec']

# %%
# for DIS-high red, KOSMOS red-ctr or red-low is approximately correct...
# for DIS-low red, might need to stich red-low and red-ihigh together? 
temp1 = pk.loadarctemplate('NeRed2.0-low.spec') # new
temp2 = pk.loadarctemplate('ArRed2.0-low.spec') # new

plt.figure(figsize=(8,3))
plt.plot(temp1.spectral_axis, temp1.flux.value, alpha=0.5)
plt.plot(temp2.spectral_axis, temp2.flux.value, alpha=0.5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# build new template from multiple KOSMOS templates
NeAr = Spectrum1D(flux=(temp1.flux.value + temp2.flux.value) * temp1.flux.unit,  
                  spectral_axis=temp1.spectral_axis)

plt.figure(figsize=(8,3))
plt.plot(NeAr.spectral_axis, NeAr.flux.value, c='C3')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
arcfile = dir + '05may31.0035r.fits' # HeNeAr lamp

# read and process in the ARC LAMP, just like a normal spectrum
arcimg = pk.proc(arcfile, bias=bias, ilum=ilum, trim=True) 

if DISPLAY:
    plt.figure(figsize=(6,3))
    plt.imshow(arcimg, origin='lower', aspect='auto', cmap=plt.cm.afmhot)
    plt.plot(np.arange(len(sci_trace.trace)), sci_trace.trace.data) # for illustration, overplot the trace 
    plt.clim(np.percentile(arcimg, (5, 97)))
    cb = plt.colorbar()
    plt.title(arcfile)
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'Mount' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.476553 from DATE-OBS'. [astropy.wcs.wcs]
# /Users/james/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py:4823: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# extract the HeNeAr spectrum for the science & calibration traces
# sciarc_ex, _ = pk.BoxcarExtract(arcimg, sci_trace, apwidth=3, skysep=5, skywidth=5)
# calarc_ex, _ = pk.BoxcarExtract(arcimg, cal_trace, apwidth=3, skysep=5, skywidth=5)


# NEW: returns BoxcarExtract, need to use.spectrum below to match previous output!
sciarc_ex = pk.BoxcarExtract(arcimg, sci_trace, apwidth=3, skysep=5, skywidth=5, bkgd_sub=False)
calarc_ex = pk.BoxcarExtract(arcimg, cal_trace, apwidth=3, skysep=5, skywidth=5, bkgd_sub=False)
# Out:
# /var/folders/8t/yh7p62792_b_y17g3f6wk0wm0000gn/T/ipykernel_16504/3199632302.py:7: DeprecationWarning: PyKOSMOS BoxcarExtract is now a wrapper for functions within specreduce.extract.
#   sciarc_ex = pk.BoxcarExtract(arcimg, sci_trace, apwidth=3, skysep=5, skywidth=5, bkgd_sub=False)
# /var/folders/8t/yh7p62792_b_y17g3f6wk0wm0000gn/T/ipykernel_16504/3199632302.py:8: DeprecationWarning: PyKOSMOS BoxcarExtract is now a wrapper for functions within specreduce.extract.
#   calarc_ex = pk.BoxcarExtract(arcimg, cal_trace, apwidth=3, skysep=5, skywidth=5, bkgd_sub=False)

# %%
# use DTW from new NeAr template to fit HeNeAr extraction 
# (even though template is missing Ar, AND the wavelength solution is BACKWARDS!)

sci_xpts, sci_wpts = pk.identify_dtw(sciarc_ex, NeAr, upsample=False, display=False, 
                   step_pattern='asymmetric', open_begin=True, open_end=True, 
                   peak_spline=False, pthreshold=0.95)

cal_xpts, cal_wpts = pk.identify_dtw(calarc_ex, NeAr, upsample=False, display=False, 
                   step_pattern='asymmetric', open_begin=True, open_end=True, 
                   peak_spline=False, pthreshold=0.95)


# apply wavelength solution to science extraction
cal_fit = pk.fit_wavelength(cal_spectrum, sci_xpts, sci_wpts, display=False, mode='poly', deg=7)
sci_fit = pk.fit_wavelength(sci_spectrum, sci_xpts, sci_wpts, display=False, mode='poly', deg=7)

# %%
# this data comes from the APO DIS red channel, which has wavelength axis backwards
# (despite not mentioning in the header...)
wapprox = (np.arange(sciimg.shape[1]) - sciimg.shape[1]/2)[::-1] * sciimg.header['DISPDW'] + sciimg.header['DISPWC']
wapprox = wapprox * u.angstrom

if DISPLAY:
    plt.figure()
    plt.errorbar(wapprox.value, sci_spectrum.flux.value, 
                 yerr=sci_spectrum.uncertainty.array, linestyle='none', label='approx from header')
    
    plt.plot(sci_fit.spectral_axis, sci_fit.flux.value, label='DTW solution')
    
    plt.xlabel(wapprox.unit)
    plt.ylabel(sci_fit.flux.unit)
    plt.legend()
    plt.title('DTW templates work!')
# Out:
# /var/folders/8t/yh7p62792_b_y17g3f6wk0wm0000gn/T/ipykernel_16504/51991804.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# You don't need to do this, it's just for illustration!!

arc_fit = pk.fit_wavelength(sciarc_ex.spectrum, sci_xpts, sci_wpts, display=False, mode='poly', deg=7)

# The old IRAF-style linelists just have 2 col: (wavelength, line name)
henear_tbl = Table.read('../pykosmos/resources/linelists/apohenear.dat', 
                        names=('wave', 'name'), format='ascii')

henear_tbl['wave'].unit = u.angstrom
apo_henear = henear_tbl['wave']

# compare NeAr template to HeNeAr
plt.figure()
plt.plot(NeAr.spectral_axis, NeAr.flux.value/ np.nanmedian(NeAr.flux.value),
         c='C3', label='NeAr new template')
plt.plot(arc_fit.spectral_axis, arc_fit.flux.value / np.nanmedian(arc_fit.flux.value), 
         c='C0', label='HeNeAr extraction')

plt.plot([],c='k', linestyle='--',alpha=0.2, label='APO HeNeAr lines')
plt.legend()

plt.vlines(apo_henear.data, 0, 2500, linestyles='--', color='k', alpha=0.2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 4. Airmass & Flux Calibration

# %%
# Get the airmass from the Headers... no fancy way to do this I guess? 
ZD = sciimg.header['ZD'] / 180.0 * np.pi
sci_airmass = 1.0/np.cos(ZD) # approximate Zenith Distance -> Airmass conversion

ZD = calimg.header['ZD'] / 180.0 * np.pi
cal_airmass = 1.0/np.cos(ZD)

print(sci_airmass, cal_airmass)
# Out:
# 1.0668455410852924 1.052300816491183

# %%
# Select the observatory-specific airmass extinction profile from the provided "extinction" library
Xfile = pk.obs_extinction('apoextinct.dat')
# Xfile

# %%
# apply the airmass correction
cal_fitX = pk.airmass_cor(cal_fit, cal_airmass, Xfile)
sci_fitX = pk.airmass_cor(sci_fit, sci_airmass, Xfile)

# %%
# Select the Standard Star reference spectrum from the provided "onedstd" library
standardstar = pk.onedstd('spec50cal/bd284211.dat')
# standardstar

# %%
# this is the sensitivity function, which converts the CCD data from
# ADU/S -> erg/s/cm2/A
sensfunc = pk.standard_sensfunc(cal_fitX, standardstar, mode='linear', display=False)

if DISPLAY:
    plt.figure(figsize=(8,3))
    plt.plot(sensfunc.spectral_axis, sensfunc.flux)
    plt.xlabel('wavelength')
    plt.ylabel('sensfunc')
    
sensfunc.flux.unit
# Out:
# Unit("erg / (Angstrom adu cm2)")
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# convert from air to vac wavelength

# sci_fitX = kosmos.air_to_vac(sci_fitX)

# %%
final_spectrum = pk.apply_sensfunc(sci_fitX, sensfunc)

if DISPLAY:
    plt.figure()
    plt.plot(final_spectrum.wavelength, final_spectrum.flux, c='k')
    # no errors in boxcar extract right now...
    plt.xlabel('Wavelength ['+str(final_spectrum.wavelength.unit)+']')
    plt.ylabel('Flux ['+str(final_spectrum.flux.unit)+']')
    plt.title('Gl 669A – workflow example reduction')
    
final_spectrum.flux.unit # units check out!
# Out:
# Unit("erg / (Angstrom s cm2)")
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Read in the IRAF-reduced version!
from astropy.nddata import CCDData
# dir = '../kosmos/testdata/slh05_test/apo05/'
img = CCDData.read('../../pykosmos_testdata/slh05_test/slh_reduction/gl669cal.fits', hdu=0)

plt.figure(figsize=(9,4))
plt.plot(final_spectrum.wavelength, final_spectrum.flux, c='k', label='New reduction', alpha=0.7)

# coefficients manually taken from the WCS info in the header, 
# b/c I can't figure out how to access them progamatically...
plt.plot(5654.8668211415 + np.arange(2006)*0.84311144412739, 
         img.data[0,0,:], label='IRAF reduction', alpha=.7)

plt.xlabel('Wavelength ['+str(final_spectrum.wavelength.unit)+']')
plt.ylabel('Flux ['+str(final_spectrum.flux.unit)+']')
plt.title('Gl 669A – APO05 example data')
plt.legend()
# Out:
# WARNING: UnitsWarning: 'erg/cm2/s/A' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]
# WARNING: FITSFixedWarning: RADECSYS= 'FK5' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 53522.384752 from DATE-OBS'. [astropy.wcs.wcs]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
