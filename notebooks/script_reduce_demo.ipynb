# %%
 # need notebook backend for interaction
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.table import Table
from astropy import units as u

# import kosmos... if we do it right this should be the only other thing to import someday!
import sys  
sys.path.append('..')

import kosmos
kosmos.__version__
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.
# '0.03'

# %%
# from astropy.nddata import CCDData
# CCDData.read.help('fits')

# %%
import warnings
from astropy.io.fits.verify import VerifyWarning
warnings.simplefilter('ignore', category=VerifyWarning)
# "ignore", category=wcs.FITSFixedWarnin
from astropy.wcs import FITSFixedWarning

warnings.simplefilter('ignore', category=FITSFixedWarning)

# %%
tbl = Table.read('kosmos_script.csv', format='csv', names=('file', 'type'))

# %%
tbl['file'][0].split('.fits')[0]+'_reduced.fits'
# Out:
# '../kosmos/testdata/UT210913/bias.0002r_reduced.fits'

# %%
kosmos.script_reduce('kosmos_script.csv', display=True, debug=True,
                     waveapprox=True, trace_guess=460, trace_window=100, stdtrace=True)
# Out:
# ../kosmos/testdata/UT210913/bias.0002r.fits bias  bias/flat
# combining 6 biases
# ../kosmos/testdata/UT210913/flat.0008r.fits flat  bias/flat
# combining 7 flats
# /Users/james/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:753: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# ../kosmos/testdata/UT210913/arc.0015r.fits  arc
# ../kosmos/testdata/UT210913/object.0018r.fits  std/object
# /Users/james/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:753: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# ../kosmos/apextract.py:297: RuntimeWarning: invalid value encountered in sqrt
#   fluxerr[i] = np.sqrt(np.nansum((onedspec[i]-skysubflux[i])) +
# ../kosmos/testdata/UT210913/object.0018r.fits  std  redcal/bd174708.dat
# saving std trace
# ...

# %%
# this is hopefully the 1-liner to run
# WORKS ON OLD APO DATA FROM SLH!
kosmos.script_reduce('apo05_script.csv', debug=True, display=True)
# Out:
# ../kosmos/testdata/slh05_test/apo05/05may31.0023r.fits bias  bias/flat
# combining 9 biases
# WARNING: FITSFixedWarning: RADECSYS= 'Mount' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'Mount' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa.
# ../kosmos/testdata/slh05_test/apo05/05may31.0037r.fits flat  bias/flat
# combining 5 flats
# /Users/james/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:753: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# ../kosmos/testdata/slh05_test/apo05/05may31.0035r.fits  arc
# ../kosmos/testdata/slh05_test/apo05/05may31.0020r.fits  std/object
# WARNING: FITSFixedWarning: RADECSYS= 'FK5' / Coordinate system, per TCC ObjSys
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# ...

# %%
# SANDBOX BELOW HERE
