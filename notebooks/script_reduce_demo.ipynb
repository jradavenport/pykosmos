# %%
 # need notebook backend for interaction
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.table import Table
from astropy import units as u

import pykosmos as pk
pk.__version__
# Out:
# '0.3'

# %%
# from astropy.nddata import CCDData
# CCDData.read.help('fits')

# %%
import warnings
from astropy.io.fits.verify import VerifyWarning
warnings.simplefilter('ignore', category=VerifyWarning)
# "ignore", category=wcs.FITSFixedWarnin
from astropy.wcs import FITSFixedWarning

warnings.simplefilter('ignore', category=FITSFixedWarning)

# %%
# tbl = Table.read('kosmos_script.csv', format='csv', names=('file', 'type'))

# %%
# tbl['file'][0].split('.fits')[0]+'_reduced.fits'

# %%
# this is hopefully the 1-liner to run
# WORKS ON OLD APO DATA FROM SLH!
pk.script_reduce('apo05_script.csv', debug=True, display=True)
# Out:
# ../../pykosmos_testdata/slh05_test/apo05/05may31.0023r.fits bias  bias/flat
# combining 9 biases
# ../../pykosmos_testdata/slh05_test/apo05/05may31.0037r.fits flat  bias/flat
# combining 5 flats
# /Users/james/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# ../../pykosmos_testdata/slh05_test/apo05/05may31.0035r.fits  arc
# ../../pykosmos_testdata/slh05_test/apo05/05may31.0020r.fits  std/object
# 19 lines matched from 20 within estimated range.
# ../../pykosmos_testdata/slh05_test/apo05/05may31.0020r.fits  std  spec50cal/bd284211.dat
# /Users/james/anaconda3/lib/python3.11/site-packages/pykosmos/apextract.py:335: RuntimeWarning: invalid value encountered in sqrt
#   fluxerr[i] = np.sqrt(np.nansum((onedspec[i]-skysubflux[i])) +
# ../../pykosmos_testdata/slh05_test/apo05/05may31.0010r.fits  std/object
# /Users/james/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:784: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /Users/james/anaconda3/lib/python3.11/site-packages/pykosmos/apextract.py:335: RuntimeWarning: invalid value encountered in sqrt
#   fluxerr[i] = np.sqrt(np.nansum((onedspec[i]-skysubflux[i])) +
# 19 lines matched from 20 within estimated range.

# %%
# pk.script_reduce('kosmos_script.csv', display=True, debug=True,
#                      waveapprox=True, trace_guess=460, trace_window=100, stdtrace=True)

# %%
# SANDBOX BELOW HERE
